# %%
import numpy as np

# %%
a1=np.array([34,76,89,11,90,'panu'])
print(a1)
# Out:
# ['34' '76' '89' '11' '90' 'panu']

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a1[1]
# Out:
# np.str_('76')

# %%
a1.size
# Out:
# 6

# %%
print(a1[1:4])
# Out:
# ['76' '89' '11']

# %%
import time
time.time()
# Out:
# 1788760705.981036

# %%
import time
l=list(range(1000000))
curr_time=time.time()
newl=[i*2 for i in l]
time_list=time.time()- curr_time
print(f"time taken by list {time_list}")
# Out:
# time taken by list 0.04284214973449707

# %%
import time
import numpy as np
arr = np.arange(1000000)
curr_time = time.time()
newarr = arr * 2
time_array = time.time() - curr_time
print(f"Time taken by NumPy array: {time_array}")
# Out:
# Time taken by NumPy array: 0.002018451690673828

# %%
np.arange(5,25)
np.arange(5,25,2.5)
# Out:
# array([ 5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5])

# %%
arr=np.array([[1,3,6],[5,6,7],[10,10,5],[2,9,5]])
print(arr)
arr.ndim
arr.size
arr.shape
# Out:
# [[ 1  3  6]
#  [ 5  6  7]
#  [10 10  5]
#  [ 2  9  5]]
# (4, 3)

# %%
arr.reshape(6,2)
# Out:
# array([[ 1,  3],
#        [ 6,  5],
#        [ 6,  7],
#        [10, 10],
#        [ 5,  2],
#        [ 9,  5]])

# %%
arr.reshape(2,3,2)
# Out:
# array([[[ 1,  3],
#         [ 6,  5],
#         [ 6,  7]],
#
#        [[10, 10],
#         [ 5,  2],
#         [ 9,  5]]])

# %%
import matplotlib.pyplot as plt
img=plt.imread('image.jpg')

# %%
plt.imshow(img)

# %%
arr
# Out:
# array([[ 1,  3,  6],
#        [ 5,  6,  7],
#        [10, 10,  5],
#        [ 2,  9,  5]])

# %%
arr[2:4,0:2]
# Out:
# array([[10, 10],
#        [ 2,  9]])

# %%
arr[[0,2,3],0:2]
# Out:
# array([[ 1,  3],
#        [10, 10],
#        [ 2,  9]])

# %%
arr1=np.array([[5,6,7],[10,10,5],[5,2,1]])
arr2=np.array([[1,3,6],[5,6,7],[10,10,5]])
arr1
# Out:
# array([[ 5,  6,  7],
#        [10, 10,  5],
#        [ 5,  2,  1]])

# %%
arr2
# Out:
# array([[ 1,  3,  6],
#        [ 5,  6,  7],
#        [10, 10,  5]])

# %%
np.linalg.det(arr1)
# Out:
# np.float64(-120.00000000000009)

# %%
np.linalg.inv(arr1)
# Out:
# array([[ 0.        , -0.06666667,  0.33333333],
#        [-0.125     ,  0.25      , -0.375     ],
#        [ 0.25      , -0.16666667,  0.08333333]])

# %%
arr1 @ arr2
# Out:
# array([[105, 121, 107],
#        [110, 140, 155],
#        [ 25,  37,  49]])
