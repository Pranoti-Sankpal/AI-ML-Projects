# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([12,23,32,40,48,51])
y=np.array([10,15,23,28,35,41])
z=np.array([56,47,40,34,29,15])

# %%
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
plt.title("trend")
plt.xlabel('x values')
plt.ylabel('y values')
plt.plot(x,y,color='black',marker='o')

# %%
import matplotlib.pyplot as plt
plt.title("trend")
plt.xlabel('x values')
plt.ylabel('y values')
plt.plot(x,y,color='black',marker='o',ls='--',mfc='green');
plt.grid()

# %%
plt.title("trend")
plt.xlabel('x values')
plt.ylabel('y values')
plt.plot(x,z,color='black',marker='o',ls='--',mfc='green');
plt.plot(x,y,color='black',marker='o',ls='--',mfc='green');

plt.grid()

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.title("trend")
plt.xlabel('x values')
plt.ylabel('y values')
plt.plot(x,z,color='black',marker='o',ls='--',mfc='green');
plt.grid()

plt.subplot(2,2,2)
plt.title("trend")
plt.xlabel('x values')
plt.ylabel('y values')
plt.plot(x,y,color='black',marker='o',ls='--',mfc='red');



plt.grid()

# %%
courses=['python','R','Lips','php','java']
enrollments=[80,65,30,55,100]

# %%
plt.bar(courses,enrollments)
plt.xlabel("course name")
plt.ylabel("students entrolled")
# Out:
# Text(0, 0.5, 'students entrolled')

# %%
plt.title("trend")
plt.xlabel('x values')
plt.ylabel('y values')
plt.bar(courses,enrollments,width=0.6,color='pink',edgecolor='black',linewidth=1.5,)
plt.xlabel("course name")
plt.ylabel("students entrolled")
# Out:
# Text(0, 0.5, 'students entrolled')

# %%
plt.pie(enrollments, labels=courses,autopct="%.2f%%");

# %%
plt.pie(enrollments, labels=courses,autopct="%.2f%%",shadow=True,explode=[0,0,0.2,0,0]);

# %%
df=pd.read_csv("student_performance_dataset.csv")
df
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
df['part_time_job'].value_counts()
# Out:
# part_time_job
# No     684
# Yes    316
# Name: count, dtype: int64

# %%
df['part_time_job'].value_counts().index
# Out:
# Index(['No', 'Yes'], dtype='str', name='part_time_job')

# %%
plt.pie(df['part_time_job'].value_counts(),labels=df['part_time_job'].value_counts().index,autopct="%.2f%%",shadow=True,explode=[0,0])

# %%
plt.boxplot(df['final_exam_score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21c4ada1bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21c4ada1e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21c4ada1a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x21c4ada20d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21c4ada2210>],
#  'means': []}

# %%
def find_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data < lower_bound) | (data > upper_bound)]

    return lower_bound, upper_bound, outliers


lower_bound, upper_bound, outliers = find_outliers(df['final_exam_score'])

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
print("Outliers:", outliers)
# Out:
# Lower Bound: 52.89999999999996
# Upper Bound: 114.70000000000003
# Outliers: 147    46.8
# Name: final_exam_score, dtype: float64

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
df.drop('student_id',axis=1,inplace=True)

# %%
plt.figure(figsize=(16,9))
sns.boxplot(df);

# %%
plt.scatter(x='sleep_hours',y='final_exam_score',data=df)

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue='species');

# %%
sns.countplot(df['parental_education']);

# %%
from sklearn.preprocessing import LabelEncoder
ndef=pd.get_dummies(df,drop_first=True)

# %%
corr=ndef.corr()
corr
# Out:
#                                 study_time_hours  attendance_percent  \
# study_time_hours                        1.000000           -0.043712
# attendance_percent                     -0.043712            1.000000
# sleep_hours                             0.005594            0.034089
# previous_grade                         -0.035700           -0.014310
# final_exam_score                        0.567513            0.261872
# gender_Male                             0.005898            0.014199
# parental_education_High School         -0.040516           -0.008375
# parental_education_Masters              0.008018           -0.002864
# parental_education_PhD                  0.037770            0.016977
# internet_access_Yes                    -0.005323           -0.001383
# extracurricular_activities_Yes         -0.003474            0.010885
# part_time_job_Yes                      -0.018981            0.048941
# final_grade_B                           0.011139            0.001473
# ...

# %%
plt.figure(figsize=(16,12))
sns.heatmap(corr,annot =True,cmap='coolwarm');

# %%
import threading
import time

# %%
def print_numbers():
    for i in range(5):
        print(f"numbers =>{i}")
def print_let():
    for j in 'abcde':
        print(f"letters =>{j}")        

t=time.time()
print_numbers()
print_let()
fin_time=time.time()-t
print(fin_time)
# Out:
# numbers =>0
# numbers =>1
# numbers =>2
# numbers =>3
# numbers =>4
# letters =>a
# letters =>b
# letters =>c
# letters =>d
# letters =>e
# 0.00047135353088378906

# %%
def print_numbers():
    for i in range(5):
        time.sleep(2)
        print(f"numbers =>{i}")
def print_let():
    for j in 'abcde':
        time.sleep(2)
        print(f"letters =>{j}")        

t=time.time()
print_numbers()
print_let()
fin_time=time.time()-t
print(fin_time)
# Out:
# numbers =>0
# numbers =>1
# numbers =>2
# numbers =>3
# numbers =>4
# letters =>a
# letters =>b
# letters =>c
# letters =>d
# letters =>e
# 20.01340937614441

# %%
def print_numbers():
    for i in range(5):
        time.sleep(2)
        print(f"numbers =>{i}")
def print_let():
    for j in 'abcde':
        time.sleep(2)
        print(f"letters =>{j}")        

t=time.time()

t1=threading.Thread(target=print_numbers)
t2=threading.Thread(target=print_let)
t1.start()
t2.start()

t1.join()
t2.join()
fin_time=time.time()-t
print(fin_time)
# Out:
# numbers =>0letters =>a
#
# letters =>bnumbers =>1
#
# numbers =>2
# letters =>c
# numbers =>3
# letters =>d
# letters =>enumbers =>4
#
# 10.017485857009888
